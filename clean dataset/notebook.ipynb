# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("Messy_Sales_Dataset_1200_Rows.xlsx")

# %%
df.head()

# %%
df.info()

# %%
df.isnull().sum()
# Out:
# Order_ID         0
# Customer_Name    0
# Email            0
# Category         0
# Sales            0
# Profit           0
# Order_Date       0
# Region           0
# Quantity         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (1175, 9)

# %%
df.describe()

# %%
df["Email"] = df["Email"].fillna("Unknown")

# %%
df["Email"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["Sales"].mean()
# Out:
# np.float64(4940.11055214724)

# %%
df["Sales"] = df["Sales"].fillna(df["Sales"].mean())

# %%
df["Sales"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["Profit"].mean()

df["Profit"] = df["Profit"].fillna(df["Profit"].mean())

df["Profit"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["Order_Date"] = pd.to_datetime(df["Order_Date"])

df.info()

# %%
df.columns
# Out:
# Index(['Order_ID', 'Customer_Name', 'Email', 'Category', 'Sales', 'Profit',
#        'Order_Date', 'Region', 'Quantity'],
#       dtype='str')

# %%
df.to_excel("Cleaned_Sales_Dataset.xlsx", index=False)
